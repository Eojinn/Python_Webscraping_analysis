# %% [markdown]
# # 5-1

# %% [markdown]
# # 5-2

# %% [markdown]
# # 5-3

# %% [markdown]
# # 5-4

# %% [markdown]
# # 5-5

# %% [markdown]
# # 5-6

# %% [markdown]
# # 5-7

# %% [markdown]
# # 5-8

# %% [markdown]
# # 5-9

# %% [markdown]
# # 5-10
