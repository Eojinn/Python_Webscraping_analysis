# %% [markdown]
# # 3-1

# %% [markdown]
# # 3-2

# %% [markdown]
# # 3-3

# %% [markdown]
# # 3-4

# %% [markdown]
# # 3-5

# %% [markdown]
# # 3-6

# %% [markdown]
# # 3-7

# %% [markdown]
# # 3-8

# %% [markdown]
# # 3-9

# %% [markdown]
# # 3-10
